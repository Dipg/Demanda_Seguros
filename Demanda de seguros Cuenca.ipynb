# %%
import pyreadstat
# 2 use read_sav to read SPSS file:
df, meta = pyreadstat.read_sav('G:\Otros ordenadores\Mi Ordenador\Proyectos\CEM\Estimación Demanda de Seguros\enemdu_persona_2021_10.sav')

# %%
df
# Out:
#        area    ciudad conglomerado panelm vivienda hogar p01  p02   p03  p04  \
# 0       1.0   10150.0       002101    002       01     1  01  1.0  35.0  1.0
# 1       1.0   10150.0       002101    002       01     1  02  2.0  33.0  2.0
# 2       1.0   10150.0       002101    002       01     1  03  2.0   7.0  3.0
# 3       1.0   10150.0       002101    002       01     1  04  2.0  13.0  7.0
# 4       1.0   10150.0       002101    002       03     1  01  2.0  64.0  1.0
# ...     ...       ...          ...    ...      ...   ...  ..  ...   ...  ...
# 30809   1.0  240352.0       002302    013       06     1  02  2.0  52.0  2.0
# 30810   1.0  240352.0       002302    013       06     1  03  1.0  23.0  3.0
# 30811   1.0  240352.0       002302    013       06     1  04  1.0  19.0  3.0
# 30812   1.0  240352.0       002302    013       07     1  01  2.0  39.0  1.0
# 30813   1.0  240352.0       002302    013       07     1  02  2.0  34.0  7.0
#
# ...
